# %%
import talib
from datetime import datetime
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
msft = yf.Ticker("MSFT")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")

# %%
hist
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.056001    0.064236    0.056001    0.061491  1031788800
# 1986-03-14    0.061491    0.064785    0.061491    0.063687   308160000
# 1986-03-17    0.063687    0.065334    0.063687    0.064785   133171200
# 1986-03-18    0.064785    0.065334    0.062589    0.063138    67766400
# 1986-03-19    0.063138    0.063687    0.061491    0.062040    47894400
# ...                ...         ...         ...         ...         ...
# 2021-09-16  303.760010  305.309998  300.760010  305.220001    19550800
# 2021-09-17  304.170013  304.500000  299.529999  299.869995    41309300
# 2021-09-20  296.329987  298.720001  289.519989  294.299988    38278700
# 2021-09-21  295.690002  297.540009  294.070007  294.799988    22364100
# 2021-09-22  296.730011  300.220001  294.510010  298.579987    26614400
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# 1986-03-14        0.0           0.0
# 1986-03-17        0.0           0.0
# 1986-03-18        0.0           0.0
# 1986-03-19        0.0           0.0
# ...               ...           ...
# 2021-09-16        0.0           0.0
# 2021-09-17        0.0           0.0
# 2021-09-20        0.0           0.0
# 2021-09-21        0.0           0.0
# 2021-09-22        0.0           0.0
#
# [8956 rows x 7 columns]

# %%
msft.quarterly_balance_sheet
# Out:
#                                     2021-06-30    2021-03-31    2020-12-31  \
# Intangible Assets                 7.800000e+09  8.127000e+09  6.555000e+09
# Total Liab                        1.917910e+11  1.743740e+11  1.739010e+11
# Total Stockholder Equity          1.419880e+11  1.345050e+11  1.302360e+11
# Other Current Liab                5.261200e+10  4.006900e+10  3.992600e+10
# Total Assets                      3.337790e+11  3.088790e+11  3.041370e+11
# Common Stock                      8.311100e+10  8.230800e+10  8.189600e+10
# Other Current Assets              1.347100e+10  1.203400e+10  1.274800e+10
# Retained Earnings                 5.705500e+10  5.073500e+10  4.497300e+10
# Other Liab                        3.168100e+10  3.160100e+10  3.158500e+10
# Good Will                         4.971100e+10  4.969800e+10  4.421900e+10
# Treasury Stock                    1.822000e+09  1.462000e+09  3.367000e+09
# Other Assets                      1.507500e+10  1.442700e+10  1.356100e+10
# Cash                              1.422400e+10  1.370200e+10  1.443200e+10
# Total Current Liabilities         8.865700e+10  7.219300e+10  6.748600e+10
# Deferred Long Term Asset Charges  7.181000e+09           NaN           NaN
# Short Long Term Debt              8.072000e+09  8.051000e+09  5.387000e+09
# Other Stockholder Equity          1.822000e+09  1.462000e+09  3.367000e+09
# Property Plant Equipment          7.080300e+10  6.561800e+10  6.203500e+10
# Total Current Assets              1.844060e+11  1.656140e+11  1.739730e+11
# Long Term Investments             5.984000e+09  5.395000e+09  3.794000e+09
# Net Tangible Assets               8.447700e+10  7.668000e+10  7.946200e+10
# Short Term Investments            1.160320e+11  1.113110e+11  1.175570e+11
# Net Receivables                   3.804300e+10  2.632200e+10  2.731200e+10
# Long Term Debt                    5.007400e+10  5.000700e+10  5.513600e+10
# Inventory                         2.636000e+09  2.245000e+09  1.924000e+09
# Accounts Payable                  1.516300e+10  1.341200e+10  1.277000e+10
#
#                                     2020-09-30
# Intangible Assets                 6.923000e+09
# Total Liab                        1.776090e+11
# Total Stockholder Equity          1.233920e+11
# Other Current Liab                4.299600e+10
# Total Assets                      3.010010e+11
# Common Stock                      8.108900e+10
# Other Current Assets              1.357200e+10
# Retained Earnings                 3.919300e+10
# Other Liab                        3.317400e+10
# Good Will                         4.389000e+10
# Treasury Stock                    3.110000e+09
# Other Assets                      1.303400e+10
# Cash                              1.720500e+10
# Total Current Liabilities         7.005600e+10
# Deferred Long Term Asset Charges           NaN
# Short Long Term Debt              6.497000e+09
# Other Stockholder Equity          3.110000e+09
# Property Plant Equipment          5.697400e+10
# Total Current Assets              1.770770e+11
# Long Term Investments             3.103000e+09
# Net Tangible Assets               7.257900e+10
# Short Term Investments            1.207440e+11
# Net Receivables                   2.285100e+10
# Long Term Debt                    5.705500e+10
# Inventory                         2.705000e+09
# Accounts Payable                  1.250900e+10

# %%
msft.quarterly_cashflow
# Out:
#                                              2021-06-30    2021-03-31  \
# Investments                               -4.334000e+09  2.517000e+09
# Change To Liabilities                      1.301400e+10  3.600000e+08
# Total Cashflows From Investing Activities -1.085300e+10 -9.684000e+09
# Total Cash From Financing Activities      -1.137100e+10 -1.319200e+10
# Change To Operating Activities             7.990000e+08  1.305000e+09
# Issuance Of Stock                          4.500000e+08  3.960000e+08
# Net Income                                 1.645800e+10  1.545700e+10
# Change In Cash                             5.220000e+08 -7.300000e+08
# Repurchase Of Stock                       -7.177000e+09 -6.930000e+09
# Effect Of Exchange Rate                    3.600000e+07 -3.300000e+07
# Total Cash From Operating Activities       2.271000e+10  2.217900e+10
# Depreciation                               2.558000e+09  2.936000e+09
# Other Cashflows From Investing Activities  4.340000e+08  4.000000e+08
# Dividends Paid                            -4.214000e+09 -4.221000e+09
# Change To Inventory                       -3.880000e+08 -3.290000e+08
# Change To Account Receivables             -1.160600e+10  2.900000e+08
# Other Cashflows From Financing Activities -4.300000e+08 -1.937000e+09
# Change To Netincome                        1.907000e+09  1.086000e+09
# Capital Expenditures                      -6.452000e+09 -5.089000e+09
# Net Borrowings                                      NaN -5.000000e+08
#
#                                              2020-12-31    2020-09-30
# Investments                                2.593000e+09  2.100000e+09
# Change To Liabilities                     -3.194000e+09 -2.749000e+09
# Total Cashflows From Investing Activities -1.669000e+09 -5.371000e+09
# Total Cash From Financing Activities      -1.363400e+10 -1.028900e+10
# Change To Operating Activities             1.879000e+09 -2.823000e+09
# Issuance Of Stock                          3.020000e+08  5.450000e+08
# Net Income                                 1.546300e+10  1.389300e+10
# Change In Cash                            -2.773000e+09  3.629000e+09
# Repurchase Of Stock                       -6.535000e+09 -6.743000e+09
# Effect Of Exchange Rate                    1.400000e+07 -4.600000e+07
# Total Cash From Operating Activities       1.251600e+10  1.933500e+10
# Depreciation                               2.761000e+09  2.645000e+09
# Other Cashflows From Investing Activities  3.270000e+08 -2.083000e+09
# Dividends Paid                            -4.230000e+09 -3.856000e+09
# Change To Inventory                        7.880000e+08 -8.080000e+08
# Change To Account Receivables             -4.008000e+09  8.843000e+09
# Other Cashflows From Financing Activities  7.900000e+07 -2.350000e+08
# Change To Netincome                        1.195000e+09  1.317000e+09
# Capital Expenditures                      -4.174000e+09 -4.907000e+09
# Net Borrowings                            -3.250000e+09 -3.250000e+09

# %%
msft.quarterly_earnings
# Out:
#              Revenue     Earnings
# Quarter
# 3Q2020   37154000000  13893000000
# 4Q2020   43076000000  15463000000
# 1Q2021   41706000000  15457000000
# 2Q2021   46152000000  16458000000

# %%
msft.recommendations
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2021-07-28 14:54:54   Credit Suisse     Outperform              main
# 2021-07-29 10:53:54       JP Morgan     Overweight              main
# 2021-08-20 18:26:16         Wedbush     Outperform              main
# 2021-09-14 12:12:00  Morgan Stanley     Overweight              main
# 2021-09-17 13:09:25        Barclays     Overweight              main
#
# [347 rows x 4 columns]

# %%
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
#  'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. Its Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, and Skype for Business, as well as related Client Access Licenses (CAL); Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. Its Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related CALs; GitHub that provides a collaboration platform and code hosting service for developers; and Azure, a cloud platform. It also offers support services and Microsoft consulting services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. Its More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; Windows Internet of Things; and MSN advertising. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. It sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. It has collaborations with Dynatrace, Inc., Morgan Stanley, Micro Focus, WPP plc, ACI Worldwide, Inc., and iCIMS, Inc., as well as a strategic relationship with Avaya Holdings Corp. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.',
#  'city': 'Redmond',
#  'phone': '425 882 8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'industry': 'Software—Infrastructure',
#  'ebitdaMargins': 0.48080003,
#  'profitMargins': 0.36451998,
#  'grossMargins': 0.68926,
#  'operatingCashflow': 76740001792,
#  'revenueGrowth': 0.213,
#  'operatingMargins': 0.41595,
#  'ebitda': 80815996928,
#  'targetLowPrice': 275,
#  'recommendationKey': 'buy',
#  'grossProfits': 115856000000,
#  'freeCashflow': 41337249792,
#  'targetMedianPrice': 330,
#  'currentPrice': 298.58,
#  'earningsGrowth': 0.486,
#  'currentRatio': 2.08,
#  'returnOnAssets': 0.13761,
#  'numberOfAnalystOpinions': 34,
#  'targetMeanPrice': 330.68,
#  'debtToEquity': 57.947,
#  'returnOnEquity': 0.47079,
#  'targetHighPrice': 411,
#  'totalCash': 130256003072,
#  'totalDebt': 82277998592,
#  'totalRevenue': 168087994368,
#  'totalCashPerShare': 17.333,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 22.272,
#  'quickRatio': 1.898,
#  'recommendationMean': 1.6,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 12.895,
#  'beta3Year': None,
#  'enterpriseToEbitda': 26.819,
#  '52WeekChange': 0.45085883,
#  'morningStarRiskRating': None,
#  'forwardEps': 10.09,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7514890240,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 18.884,
#  'sharesShort': 45696881,
#  'sharesPercentSharesOut': 0.0061000003,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1625011200,
#  'heldPercentInstitutions': 0.71729,
#  'netIncomeToCommon': 61270999040,
#  'trailingEps': 8.05,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.3411579,
#  'priceToBook': 15.811268,
#  'heldPercentInsiders': 0.0008,
#  'nextFiscalYearEnd': 1688083200,
#  'yield': None,
#  'mostRecentQuarter': 1625011200,
#  'shortRatio': 2.28,
#  'sharesShortPreviousMonthDate': 1627603200,
#  'floatShares': 7506925463,
#  'beta': 0.77893,
#  'enterpriseValue': 2167411965952,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.469,
#  'priceToSalesTrailing12Months': 13.348936,
#  'dateShortInterest': 1630368000,
#  'pegRatio': 2.24,
#  'ytdReturn': None,
#  'forwardPE': 29.591673,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0061000003,
#  'sharesShortPriorMonth': 47983963,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 294.8,
#  'regularMarketOpen': 296.725,
#  'twoHundredDayAverage': 266.74652,
#  'trailingAnnualDividendYield': 0.007598372,
#  'payoutRatio': 0.272,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 300.21,
#  'navPrice': None,
#  'averageDailyVolume10Day': 27909357,
#  'regularMarketPreviousClose': 294.8,
#  'fiftyDayAverage': 296.94794,
#  'trailingAnnualDividendRate': 2.24,
#  'open': 296.725,
#  'toCurrency': None,
#  'averageVolume10days': 27909357,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.48,
#  'exDividendDate': 1637107200,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 294.51,
#  'currency': 'USD',
#  'trailingPE': 37.09068,
#  'regularMarketVolume': 26626342,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2243795877888,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 22362590,
#  'dayLow': 294.51,
#  'ask': 0,
#  'askSize': 1000,
#  'volume': 26626342,
#  'fiftyTwoWeekHigh': 305.84,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.51,
#  'fiftyTwoWeekLow': 199.2,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': 0.0084,
#  'bidSize': 800,
#  'dayHigh': 300.21,
#  'regularMarketPrice': 298.58,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com'}

# %%
df = pd.concat([msft.quarterly_balance_sheet, msft.quarterly_cashflow],ignore_index=False)

# %%
df
# Out:
#                                              2021-06-30    2021-03-31  \
# Intangible Assets                          7.800000e+09  8.127000e+09
# Total Liab                                 1.917910e+11  1.743740e+11
# Total Stockholder Equity                   1.419880e+11  1.345050e+11
# Other Current Liab                         5.261200e+10  4.006900e+10
# Total Assets                               3.337790e+11  3.088790e+11
# Common Stock                               8.311100e+10  8.230800e+10
# Other Current Assets                       1.347100e+10  1.203400e+10
# Retained Earnings                          5.705500e+10  5.073500e+10
# Other Liab                                 3.168100e+10  3.160100e+10
# Good Will                                  4.971100e+10  4.969800e+10
# Treasury Stock                             1.822000e+09  1.462000e+09
# Other Assets                               1.507500e+10  1.442700e+10
# Cash                                       1.422400e+10  1.370200e+10
# Total Current Liabilities                  8.865700e+10  7.219300e+10
# Deferred Long Term Asset Charges           7.181000e+09           NaN
# Short Long Term Debt                       8.072000e+09  8.051000e+09
# Other Stockholder Equity                   1.822000e+09  1.462000e+09
# Property Plant Equipment                   7.080300e+10  6.561800e+10
# Total Current Assets                       1.844060e+11  1.656140e+11
# Long Term Investments                      5.984000e+09  5.395000e+09
# Net Tangible Assets                        8.447700e+10  7.668000e+10
# Short Term Investments                     1.160320e+11  1.113110e+11
# Net Receivables                            3.804300e+10  2.632200e+10
# Long Term Debt                             5.007400e+10  5.000700e+10
# Inventory                                  2.636000e+09  2.245000e+09
# Accounts Payable                           1.516300e+10  1.341200e+10
# Investments                               -4.334000e+09  2.517000e+09
# Change To Liabilities                      1.301400e+10  3.600000e+08
# Total Cashflows From Investing Activities -1.085300e+10 -9.684000e+09
# Total Cash From Financing Activities      -1.137100e+10 -1.319200e+10
# Change To Operating Activities             7.990000e+08  1.305000e+09
# Issuance Of Stock                          4.500000e+08  3.960000e+08
# Net Income                                 1.645800e+10  1.545700e+10
# Change In Cash                             5.220000e+08 -7.300000e+08
# Repurchase Of Stock                       -7.177000e+09 -6.930000e+09
# Effect Of Exchange Rate                    3.600000e+07 -3.300000e+07
# Total Cash From Operating Activities       2.271000e+10  2.217900e+10
# Depreciation                               2.558000e+09  2.936000e+09
# Other Cashflows From Investing Activities  4.340000e+08  4.000000e+08
# Dividends Paid                            -4.214000e+09 -4.221000e+09
# Change To Inventory                       -3.880000e+08 -3.290000e+08
# Change To Account Receivables             -1.160600e+10  2.900000e+08
# Other Cashflows From Financing Activities -4.300000e+08 -1.937000e+09
# Change To Netincome                        1.907000e+09  1.086000e+09
# Capital Expenditures                      -6.452000e+09 -5.089000e+09
# Net Borrowings                                      NaN -5.000000e+08
#
#                                              2020-12-31    2020-09-30
# Intangible Assets                          6.555000e+09  6.923000e+09
# Total Liab                                 1.739010e+11  1.776090e+11
# Total Stockholder Equity                   1.302360e+11  1.233920e+11
# Other Current Liab                         3.992600e+10  4.299600e+10
# Total Assets                               3.041370e+11  3.010010e+11
# Common Stock                               8.189600e+10  8.108900e+10
# Other Current Assets                       1.274800e+10  1.357200e+10
# Retained Earnings                          4.497300e+10  3.919300e+10
# Other Liab                                 3.158500e+10  3.317400e+10
# Good Will                                  4.421900e+10  4.389000e+10
# Treasury Stock                             3.367000e+09  3.110000e+09
# Other Assets                               1.356100e+10  1.303400e+10
# Cash                                       1.443200e+10  1.720500e+10
# Total Current Liabilities                  6.748600e+10  7.005600e+10
# Deferred Long Term Asset Charges                    NaN           NaN
# Short Long Term Debt                       5.387000e+09  6.497000e+09
# Other Stockholder Equity                   3.367000e+09  3.110000e+09
# Property Plant Equipment                   6.203500e+10  5.697400e+10
# Total Current Assets                       1.739730e+11  1.770770e+11
# Long Term Investments                      3.794000e+09  3.103000e+09
# Net Tangible Assets                        7.946200e+10  7.257900e+10
# Short Term Investments                     1.175570e+11  1.207440e+11
# Net Receivables                            2.731200e+10  2.285100e+10
# Long Term Debt                             5.513600e+10  5.705500e+10
# Inventory                                  1.924000e+09  2.705000e+09
# Accounts Payable                           1.277000e+10  1.250900e+10
# Investments                                2.593000e+09  2.100000e+09
# Change To Liabilities                     -3.194000e+09 -2.749000e+09
# Total Cashflows From Investing Activities -1.669000e+09 -5.371000e+09
# Total Cash From Financing Activities      -1.363400e+10 -1.028900e+10
# Change To Operating Activities             1.879000e+09 -2.823000e+09
# Issuance Of Stock                          3.020000e+08  5.450000e+08
# Net Income                                 1.546300e+10  1.389300e+10
# Change In Cash                            -2.773000e+09  3.629000e+09
# Repurchase Of Stock                       -6.535000e+09 -6.743000e+09
# Effect Of Exchange Rate                    1.400000e+07 -4.600000e+07
# Total Cash From Operating Activities       1.251600e+10  1.933500e+10
# Depreciation                               2.761000e+09  2.645000e+09
# Other Cashflows From Investing Activities  3.270000e+08 -2.083000e+09
# Dividends Paid                            -4.230000e+09 -3.856000e+09
# Change To Inventory                        7.880000e+08 -8.080000e+08
# Change To Account Receivables             -4.008000e+09  8.843000e+09
# Other Cashflows From Financing Activities  7.900000e+07 -2.350000e+08
# Change To Netincome                        1.195000e+09  1.317000e+09
# Capital Expenditures                      -4.174000e+09 -4.907000e+09
# Net Borrowings                            -3.250000e+09 -3.250000e+09

# %%
msft_historical[freeCashflow]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-3c73965194d9> in <module>
# ----> 1 msft_historical[freeCashflow]
#
# NameError: name 'msft_historical' is not defined

# %%
sns.countplot(hist['Volume'])
# Out:
# C:\Users\14077\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume', ylabel='count'>
